# %%
#importing required packages
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
pd.options.display.max_columns =None
pd.options.display.max_rows =None

# %%
#loading the data
df  = pd.read_csv("C:\\Users\\ISHA KHANDELWAL\\Downloads\MLP_Datase.csv")

df.head()
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
## DATA PRE-PROCESSING

#Finding out missing values in each column
print(df.isna().sum())
missing_status=df.isna().sum()
##print(df.isnull().sum())
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
##Handling the missing data with 0 value
df = df.fillna(0)
print(df.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
print(df.isna().sum())
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#FInding rows that have duplicate values
df[df.duplicated(keep = 'last')]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
# Size of the dataset
df.shape
# Out:
# (614, 13)

# %%
#Examining the column names and the datatypes
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#Finding number of unique values in each column
df.nunique()
# Out:
# Loan_ID              614
# Gender                 3
# Married                3
# Dependents             5
# Education              2
# Self_Employed          3
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           204
# Loan_Amount_Term      11
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
# List all columns
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#Statistical understanding about the numerical data
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  141.166124        334.201954
# std        6109.041673        2926.248369   88.340630         82.183884
# min         150.000000           0.000000    0.000000          0.000000
# 25%        2877.500000           0.000000   98.000000        360.000000
# 50%        3812.500000        1188.500000  125.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.773616
# std          0.418832
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Find out how many individuals are graduate and non graduate
df.groupby(['Education']).size()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# dtype: int64

# %%
#Randomly sampling 10 rows
df.sample(n=10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 176  LP001608    Male     Yes          2      Graduate            No
# 326  LP002068    Male      No          0      Graduate            No
# 216  LP001722    Male     Yes          0      Graduate            No
# 380  LP002226    Male     Yes          0      Graduate             0
# 389  LP002250    Male     Yes          0      Graduate            No
# 308  LP001996    Male      No          0      Graduate            No
# 346  LP002130    Male     Yes          0  Not Graduate            No
# 513  LP002648    Male     Yes          0      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 428  LP002369    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 176             2045        1619.000000       101.0             360.0
# 326             4917           0.000000       130.0             360.0
# 216              150        1800.000000       135.0             360.0
# 380             3333        2500.000000       128.0             360.0
# 389             5488           0.000000       125.0             360.0
# 308            20233           0.000000       480.0             360.0
# 346             3523        3230.000000       152.0             360.0
# 513             2130        6666.000000        70.0             180.0
# 219             4283        2383.000000       127.0             360.0
# 428             2920          16.120001        87.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 176             1.0         Rural           Y
# 326             0.0         Rural           Y
# 216             1.0         Rural           N
# 380             1.0     Semiurban           Y
# 389             1.0         Rural           Y
# 308             1.0         Rural           N
# 346             0.0         Rural           N
# 513             1.0     Semiurban           N
# 219             0.0     Semiurban           Y
# 428             1.0         Rural           Y

# %%
#Making a new column based on calcualtion of other columns in the df
df['Total Income'] = (df['ApplicantIncome'] + df['CoapplicantIncome'])
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total Income
# 0             1.0         Urban           Y        5849.0
# 1             1.0         Rural           N        6091.0
# 2             1.0         Urban           Y        3000.0
# 3             1.0         Urban           Y        4941.0
# 4             1.0         Urban           Y        6000.0

# %%
df[(df.Gender=='Male') & (df.Loan_Status=='Y')].head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total Income
# 0             1.0         Urban           Y        5849.0
# 2             1.0         Urban           Y        3000.0
# 3             1.0         Urban           Y        4941.0
# 4             1.0         Urban           Y        6000.0
# 5             1.0         Urban           Y        9613.0
